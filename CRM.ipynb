# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Extraction-de-la-base-de-donnée" data-toc-modified-id="Extraction-de-la-base-de-donnée-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Extraction de la base de donnée</a></span></li><li><span><a href="#Analyse-Exploratoire" data-toc-modified-id="Analyse-Exploratoire-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Analyse Exploratoire</a></span></li></ul></div>

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# # Extraction de la base de donnée

# %%
con = sqlite3.connect('batch_1.db')

# %%
cursor = con.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('aeroports',), ('compagnies',), ('vols',)]

# %%
df_aeroports =  pd.read_sql('SELECT * from aeroports', con)

# %%
df_aeroports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 9 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   CODE IATA                                        321 non-null    object
#  1   NOM                                              321 non-null    object
#  2   LIEU                                             321 non-null    object
#  3   PAYS                                             321 non-null    object
#  4   LONGITUDE                                        321 non-null    object
#  5   LATITUDE                                         321 non-null    object
#  6   HAUTEUR                                          321 non-null    float64
#  7   PRIX RETARD PREMIERE 10 MINUTES                  321 non-null    int64
#  8   PRIS RETARD POUR CHAQUE MINUTE APRES 10 MINUTES  321 non-null    int64
# ...

# %%
df_aeroports
# Out:
#     CODE IATA                                 NOM         LIEU PAYS  \
# 0         MCT        Muscat International Airport       Muscat   OM
# 1         SOU                 Southampton Airport  Southampton   GB
# 2         PNH    Phnom Penh International Airport   Phnom Penh   KH
# 3         BLR    Kempegowda International Airport    Bangalore   IN
# 4         FFD                        RAF Fairford     Fairford   GB
# ..        ...                                 ...          ...  ...
# 316       PFO        Paphos International Airport       Paphos   CY
# 317       MLE         MalÃ© International Airport        MalÃ©   MV
# 318       XMN  Xiamen Gaoqi International Airport       Xiamen   CN
# 319       SUB        Juanda International Airport     Surabaya   ID
# 320       HND  Tokyo Haneda International Airport        Tokyo   JP
#
#                LONGITUDE              LATITUDE  HAUTEUR  \
# 0     58.284400939941406    23.593299865722656     48.0
# ...

# %%
df_compagnies =  pd.read_sql('SELECT * from compagnies', con)

# %%
df_compagnies
# Out:
#                        COMPAGNIE   CODE
# 0              Try Hard Airlines    THA
# 1     Corporate Overlord Airways    COA
# 2             Neverland Airlines     NA
# 3       Always A Problem Flights   AAPF
# 4                 Overpriced Air     OA
# 5    Morally Ambiguious Fligthts    MAF
# 6       Fliying Is Possible Inc.   FIPI
# 7     Air Piloter Sans Les Mains  APSLM
# 8     Ne Va Pas Partout Airlines  NVPPA
# 9                 IE 6.0 Flights    I6F
# 10                   Air Penguin     AP
# 11                       Bel Air  SMITH
# 12  Better Take A Train Airlines  BTATA

# %%
df_vols =  pd.read_sql('SELECT * from vols', con)

# %%
df_vols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 30 columns):
#  #   Column                                         Dtype
# ---  ------                                         -----
#  0   IDENTIFIANT                                    int64
#  1   VOL                                            int64
#  2   CODE AVION                                     object
#  3   AEROPORT DEPART                                object
#  4   AEROPORT ARRIVEE                               object
#  5   DEPART PROGRAMME                               int64
#  6   HEURE DE DEPART                                float64
#  7   RETART DE DEPART                               float64
#  8   TEMPS DE DEPLACEMENT A TERRE AU DECOLLAGE      float64
#  9   DECOLLAGE                                      float64
#  10  TEMPS PROGRAMME                                float64
#  11  TEMPS PASSE                                    float64
# ...

# %%
df_vols
# Out:
#          IDENTIFIANT   VOL  CODE AVION AEROPORT DEPART AEROPORT ARRIVEE  \
# 0             651373  2317  28fa5df4d7             TIA              DSS
# 1            4153042  1755  4b31cd6358             MPM              BOH
# 2            3617513   804  f3e0769c08             TRN              TNA
# 3            1829601   263  2ba258e5c4             BRU              SXF
# 4            1250864  4511  11e7ffe99f             VCE              AAL
# ...              ...   ...         ...             ...              ...
# 2999995       782415   769  eb935c21e5             AGP              GOI
# 2999996      2046281  1233  208b41519d             DUR              MPM
# 2999997      1996895   323  770ec5ae7b             BOH              HAN
# 2999998      5294861  3626  5babf41084             DXB              PMI
# 2999999       280843  1150  55d6361695             VIE              BRU
#
#          DEPART PROGRAMME  HEURE DE DEPART  RETART DE DEPART  \
# ...

# %%
#df_compagnies.to_csv('compagnies.csv')
#df_aeroports.to_csv('aeroports.csv')
#df_vols.to_csv('vols.csv')

# %% [markdown]
# # Analyse Exploratoire
